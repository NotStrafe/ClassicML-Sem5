# %% [markdown]
# # Лабораторная работ №3 - "Подбор гиперпараметров модели" (ИНДИВИДУАЛЬНАЯ)
#
# ---
#
# ##### *Выполнил*: Крушинин Н.Г.
# ##### *Группа*: М8О-307Б-23
# ##### *Датасет (ссылка)*: [\*тык\*](https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud)
#
# ---

# %% [markdown]
# # Задание:
#
# 0. Выбрать модель для обучения (Desicion tree, Random forest, SVM, KNN, Boosting)
# 1. Показать какие гиперпараметры есть у выбранной модели (В виде таблички).
# 2. Выбрать датасет для обучения и взависимости от модели подготовить данные
# 3. Подобрать гиперпараметры для модели и сравнить лучшие подборы, для (Grid Search, RandomSearch, Optuna)
# 4. На самом лучшем обучении (Grid Search, RandomSearch, Optuna) сделать калькулятор, который показывает `локальную интерпретацию` с помощью [LIME](https://habr.com/ru/companies/otus/articles/779430/) и `глобальную интерпретацию` с помощью [SHAP](https://habr.com/ru/companies/ods/articles/599573/).
#
#     [Доп статья](https://habr.com/ru/companies/wunderfund/articles/739744/)

# %% [markdown]
# # 0. Глобальная настройка

# %%
RND_SEED = 42

# %% [markdown]
# # 1. Подготовка данных

# %%
import kagglehub
import pandas as pd
from kagglehub import KaggleDatasetAdapter

file_path = "creditcard.csv"

df = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "mlg-ulb/creditcardfraud",
    file_path,
)

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
# 5  0.105915  0.253844  0.081080    3.67      0
# 6 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.051634 -1.206921 -1.085339   40.80      0
# 8 -0.384157  0.011747  0.142404   93.20      0
# 9  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split


X, y = df.drop("Class", axis=1), df["Class"]
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=RND_SEED)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier


model_forest = RandomForestClassifier(
    n_estimators=100,
    criterion="gini",
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    max_features="sqrt",
    bootstrap=True,
    random_state=RND_SEED,
    n_jobs=-1,
    class_weight="balanced",
    min_impurity_decrease=0.0
)


pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("classifier", model_forest)
])

pipeline
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier',
#                  RandomForestClassifier(class_weight='balanced', n_jobs=-1,
#                                         random_state=42))])

# %%
param_grid = {
    "classifier__criterion": ["entropy"],
    "classifier__max_depth": [None, 5],
    "classifier__min_samples_split": [2, 10],
    "classifier__min_samples_leaf": [1, 4],
    "classifier__max_features": ["sqrt", 0.5]
}

# %% [markdown]
# # 2.1. Grid Search

# %%
import os
import warnings

# Перед любыми fit()/GridSearch — чтобы унаследовали подпроцессы joblib
os.environ["PYTHONWARNINGS"] = "ignore:::pkg_resources"

# На всякий случай приглушим и на уровне интерпретатора
warnings.filterwarnings("ignore", category=UserWarning, module="pkg_resources")

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold


cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=RND_SEED)

# ── Меняем только параметры под дисбаланс: метрики и refit ──
gs_tree = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    scoring={"pr": "average_precision", "roc": "roc_auc"},
    refit="pr",
    cv=cv,
    n_jobs=-1,
    verbose=3,
    return_train_score=True
)

gs_tree.fit(X_train, y_train)

print("\nЛучшие параметры:")
for key, value in gs_tree.best_params_.items():
    print(f"{key} -> {value}")
print("\nЛучшая средняя PR-AUC (CV):",
      gs_tree.cv_results_["mean_test_pr"][gs_tree.best_index_])
print("Соответствующий ROC-AUC (CV):",
      gs_tree.cv_results_["mean_test_roc"][gs_tree.best_index_])

print("Точность на тесте:", gs_tree.score(X_test, y_test))
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 3/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.866) roc: (train=1.000, test=0.961) total time= 1.5min
# [CV 3/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.985, test=0.860) roc: (train=1.000, test=0.953) total time= 1.5min
# [CV 1/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.884) roc: (train=1.000, test=0.961) total time= 1.5min
# [CV 2/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.997, test=0.823) roc: (train=1.000, test=0.959) total time= 1.5min
# [CV 1/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.980, test=0.877) roc: (train=1.000, test=0.965) total time= 1.5min
# [CV 3/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.996, test=0.853) roc: (train=1.000, test=0.966) total time= 1.5min
# [CV 4/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.983, test=0.853) roc: (train=1.000, test=0.940) total time= 1.5min
# [CV 1/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.996, test=0.887) roc: (train=1.000, test=0.979) total time= 1.5min
# [CV 4/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.996, test=0.856) roc: (train=1.000, test=0.947) total time= 1.5min
# [CV 2/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.823) roc: (train=1.000, test=0.954) total time= 1.5min
# [CV 4/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.854) roc: (train=1.000, test=0.935) total time= 1.5min
# [CV 5/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.996, test=0.765) roc: (train=1.000, test=0.927) total time= 1.5min
# [CV 2/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.983, test=0.804) roc: (train=1.000, test=0.965) total time= 1.5min
# [CV 5/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.773) roc: (train=1.000, test=0.916) total time= 1.5min
# [CV 3/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.983, test=0.851) roc: (train=1.000, test=0.959) total time= 1.4min
# [CV 5/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.984, test=0.765) roc: (train=1.000, test=0.945) total time= 1.5min
# [CV 1/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.981, test=0.878) roc: (train=1.000, test=0.972) total time= 1.5min
# [CV 5/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.981, test=0.750) roc: (train=1.000, test=0.918) total time= 1.5min
# [CV 2/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.983, test=0.826) roc: (train=1.000, test=0.958) total time= 1.5min
# [CV 4/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.979, test=0.847) roc: (train=1.000, test=0.939) total time= 1.5min
# [CV 3/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.857) roc: (train=1.000, test=0.948) total time= 3.8min
# [CV 3/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.998, test=0.856) roc: (train=1.000, test=0.967) total time= 3.8min
# [CV 1/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.995, test=0.888) roc: (train=1.000, test=0.960) total time= 3.9min
# [CV 1/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.887) roc: (train=1.000, test=0.961) total time= 3.9min
# [CV 2/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.795) roc: (train=1.000, test=0.960) total time= 4.0min
# [CV 2/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.997, test=0.775) roc: (train=1.000, test=0.953) total time= 4.0min
# [CV 4/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.854) roc: (train=1.000, test=0.942) total time= 4.2min
# [CV 5/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.778) roc: (train=1.000, test=0.916) total time= 4.2min
# [CV 1/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.983, test=0.893) roc: (train=1.000, test=0.973) total time= 3.6min
# [CV 3/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.987, test=0.869) roc: (train=1.000, test=0.967) total time= 3.7min
# [CV 4/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.997, test=0.851) roc: (train=1.000, test=0.934) total time= 3.9min
# [CV 2/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.986, test=0.811) roc: (train=1.000, test=0.953) total time= 3.9min
# [CV 5/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.997, test=0.778) roc: (train=1.000, test=0.927) total time= 3.9min
# [CV 4/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.982, test=0.857) roc: (train=1.000, test=0.947) total time= 3.9min
# [CV 2/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.975, test=0.793) roc: (train=1.000, test=0.979) total time= 1.2min
# [CV 1/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.974, test=0.851) roc: (train=1.000, test=0.986) total time= 1.2min
# [CV 3/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.969, test=0.843) roc: (train=1.000, test=0.977) total time= 1.2min
# [CV 4/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.970, test=0.838) roc: (train=1.000, test=0.969) total time= 1.4min
# [CV 1/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.969, test=0.860) roc: (train=1.000, test=0.978) total time= 1.3min
# [CV 5/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.968, test=0.751) roc: (train=1.000, test=0.941) total time= 1.3min
# [CV 2/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.971, test=0.784) roc: (train=1.000, test=0.990) total time= 1.3min
# [CV 3/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.969, test=0.844) roc: (train=1.000, test=0.976) total time= 1.4min
# [CV 4/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.966, test=0.841) roc: (train=1.000, test=0.971) total time= 1.4min
# [CV 5/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.966, test=0.737) roc: (train=1.000, test=0.960) total time= 1.4min
# [CV 3/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.982, test=0.864) roc: (train=1.000, test=0.973) total time= 3.6min
# [CV 5/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.986, test=0.773) roc: (train=1.000, test=0.933) total time= 3.8min
# [CV 1/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.971, test=0.870) roc: (train=1.000, test=0.991) total time= 1.3min
# [CV 2/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.985, test=0.802) roc: (train=1.000, test=0.965) total time= 3.8min
# [CV 1/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.982, test=0.881) roc: (train=1.000, test=0.966) total time= 3.8min
# [CV 4/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.980, test=0.853) roc: (train=1.000, test=0.947) total time= 3.8min
# [CV 2/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.976, test=0.790) roc: (train=1.000, test=0.983) total time= 1.3min
# [CV 3/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.975, test=0.850) roc: (train=1.000, test=0.976) total time= 1.2min
# [CV 4/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.972, test=0.841) roc: (train=1.000, test=0.969) total time= 1.3min
# [CV 5/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.972, test=0.749) roc: (train=1.000, test=0.960) total time= 1.3min
# [CV 1/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.970, test=0.867) roc: (train=1.000, test=0.993) total time= 1.2min
# [CV 5/5] END classifier__criterion=gini, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.984, test=0.775) roc: (train=1.000, test=0.945) total time= 4.0min
# [CV 2/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.972, test=0.789) roc: (train=1.000, test=0.979) total time= 1.3min
# [CV 3/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.971, test=0.850) roc: (train=1.000, test=0.983) total time= 1.2min
# [CV 4/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.970, test=0.845) roc: (train=1.000, test=0.972) total time= 1.3min
# [CV 5/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.969, test=0.747) roc: (train=1.000, test=0.975) total time= 1.3min
# [CV 1/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.923, test=0.816) roc: (train=1.000, test=0.976) total time= 3.7min
# [CV 3/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.942, test=0.830) roc: (train=1.000, test=0.973) total time= 3.8min
# [CV 2/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.944, test=0.754) roc: (train=1.000, test=0.986) total time= 3.8min
# [CV 1/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.941, test=0.835) roc: (train=1.000, test=0.977) total time= 3.7min
# [CV 3/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.949, test=0.836) roc: (train=1.000, test=0.982) total time= 3.7min
# [CV 5/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.944, test=0.710) roc: (train=1.000, test=0.948) total time= 3.9min
# [CV 2/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.950, test=0.759) roc: (train=1.000, test=0.986) total time= 3.7min
# [CV 4/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.951, test=0.823) roc: (train=1.000, test=0.946) total time= 4.0min
# [CV 1/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.962, test=0.848) roc: (train=1.000, test=0.987) total time= 3.8min
# [CV 2/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.968, test=0.800) roc: (train=1.000, test=0.983) total time= 3.8min
# [CV 5/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.940, test=0.703) roc: (train=1.000, test=0.963) total time= 4.0min
# [CV 4/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.948, test=0.819) roc: (train=1.000, test=0.954) total time= 4.0min
# [CV 3/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.963, test=0.851) roc: (train=1.000, test=0.976) total time= 3.5min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.888) roc: (train=1.000, test=0.960) total time= 1.1min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.831) roc: (train=1.000, test=0.954) total time= 1.2min
# [CV 4/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.960, test=0.832) roc: (train=1.000, test=0.958) total time= 4.0min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.874) roc: (train=1.000, test=0.974) total time= 1.2min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.867) roc: (train=1.000, test=0.942) total time= 1.3min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.777) roc: (train=1.000, test=0.909) total time= 1.3min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.997, test=0.893) roc: (train=1.000, test=0.972) total time= 1.3min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.998, test=0.796) roc: (train=1.000, test=0.965) total time= 1.3min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.998, test=0.862) roc: (train=1.000, test=0.960) total time= 1.3min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.998, test=0.858) roc: (train=1.000, test=0.946) total time= 1.3min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.997, test=0.778) roc: (train=1.000, test=0.921) total time= 1.3min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.990, test=0.894) roc: (train=1.000, test=0.972) total time= 1.3min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.992, test=0.828) roc: (train=1.000, test=0.965) total time= 1.3min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.990, test=0.858) roc: (train=1.000, test=0.966) total time= 1.3min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.988, test=0.856) roc: (train=1.000, test=0.953) total time= 1.3min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.991, test=0.764) roc: (train=1.000, test=0.932) total time= 1.3min
# [CV 1/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.961, test=0.848) roc: (train=1.000, test=0.988) total time= 3.5min
# [CV 5/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.965, test=0.749) roc: (train=1.000, test=0.967) total time= 3.7min
# [CV 3/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.959, test=0.850) roc: (train=1.000, test=0.976) total time= 3.5min
# [CV 2/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.968, test=0.788) roc: (train=1.000, test=0.985) total time= 3.6min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.987, test=0.888) roc: (train=1.000, test=0.972) total time= 1.1min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.989, test=0.860) roc: (train=1.000, test=0.965) total time= 1.1min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.990, test=0.820) roc: (train=1.000, test=0.966) total time= 1.2min
# [CV 4/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.959, test=0.829) roc: (train=1.000, test=0.955) total time= 3.9min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.987, test=0.855) roc: (train=1.000, test=0.940) total time= 1.1min
# [CV 5/5] END classifier__criterion=gini, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.965, test=0.749) roc: (train=1.000, test=0.966) total time= 3.9min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.990, test=0.764) roc: (train=1.000, test=0.925) total time= 1.1min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.899) roc: (train=1.000, test=0.973) total time= 3.1min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.813) roc: (train=1.000, test=0.954) total time= 3.2min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.854) roc: (train=1.000, test=0.967) total time= 3.1min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.860) roc: (train=1.000, test=0.941) total time= 3.2min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.999, test=0.896) roc: (train=1.000, test=0.967) total time= 3.0min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.998, test=0.868) roc: (train=1.000, test=0.973) total time= 2.9min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.788) roc: (train=1.000, test=0.922) total time= 3.1min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=1.000, test=0.818) roc: (train=1.000, test=0.966) total time= 3.2min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.999, test=0.789) roc: (train=1.000, test=0.933) total time= 3.1min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.992, test=0.871) roc: (train=1.000, test=0.967) total time= 3.0min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.989, test=0.899) roc: (train=1.000, test=0.966) total time= 3.1min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.999, test=0.866) roc: (train=1.000, test=0.954) total time= 3.1min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.994, test=0.820) roc: (train=1.000, test=0.966) total time= 3.2min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.990, test=0.862) roc: (train=1.000, test=0.941) total time= 3.2min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.994, test=0.889) roc: (train=1.000, test=0.979) total time= 1.2min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.996, test=0.802) roc: (train=1.000, test=0.979) total time= 1.3min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.995, test=0.856) roc: (train=1.000, test=0.972) total time= 1.3min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.993, test=0.848) roc: (train=1.000, test=0.955) total time= 1.3min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.996, test=0.775) roc: (train=1.000, test=0.955) total time= 1.3min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.990, test=0.878) roc: (train=1.000, test=0.993) total time= 1.3min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.993, test=0.808) roc: (train=1.000, test=0.989) total time= 1.3min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.991, test=0.858) roc: (train=1.000, test=0.980) total time= 1.3min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.991, test=0.856) roc: (train=1.000, test=0.973) total time= 1.3min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.992, test=0.775) roc: (train=1.000, test=0.932) total time= 3.1min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.992, test=0.771) roc: (train=1.000, test=0.970) total time= 1.2min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.989, test=0.894) roc: (train=1.000, test=0.966) total time= 3.0min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.987, test=0.881) roc: (train=1.000, test=0.987) total time= 1.2min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.989, test=0.810) roc: (train=1.000, test=0.983) total time= 1.2min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.988, test=0.854) roc: (train=1.000, test=0.983) total time= 1.2min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.984, test=0.853) roc: (train=1.000, test=0.972) total time= 1.2min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.992, test=0.812) roc: (train=1.000, test=0.972) total time= 3.1min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.991, test=0.776) roc: (train=1.000, test=0.920) total time= 2.9min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.991, test=0.874) roc: (train=1.000, test=0.966) total time= 3.0min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.988, test=0.770) roc: (train=1.000, test=0.973) total time= 1.2min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.989, test=0.858) roc: (train=1.000, test=0.947) total time= 3.1min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.986, test=0.879) roc: (train=1.000, test=0.986) total time= 1.2min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.988, test=0.804) roc: (train=1.000, test=0.985) total time= 1.2min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.986, test=0.851) roc: (train=1.000, test=0.982) total time= 1.2min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.984, test=0.851) roc: (train=1.000, test=0.975) total time= 1.2min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.988, test=0.776) roc: (train=1.000, test=0.972) total time= 1.2min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.993, test=0.893) roc: (train=1.000, test=0.986) total time= 3.0min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.991, test=0.893) roc: (train=1.000, test=0.980) total time= 3.0min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.995, test=0.856) roc: (train=1.000, test=0.968) total time= 3.1min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.997, test=0.797) roc: (train=1.000, test=0.977) total time= 3.1min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.997, test=0.782) roc: (train=1.000, test=0.964) total time= 3.1min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.993, test=0.789) roc: (train=1.000, test=0.986) total time= 3.1min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.994, test=0.854) roc: (train=1.000, test=0.960) total time= 3.2min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.993, test=0.862) roc: (train=1.000, test=0.968) total time= 3.1min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.991, test=0.853) roc: (train=1.000, test=0.964) total time= 3.1min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.994, test=0.776) roc: (train=1.000, test=0.961) total time= 3.1min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.988, test=0.899) roc: (train=1.000, test=0.988) total time= 2.8min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.991, test=0.857) roc: (train=1.000, test=0.975) total time= 2.8min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.992, test=0.800) roc: (train=1.000, test=0.986) total time= 2.8min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.988, test=0.853) roc: (train=1.000, test=0.959) total time= 2.8min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.987, test=0.896) roc: (train=1.000, test=0.975) total time= 1.6min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.991, test=0.773) roc: (train=1.000, test=0.959) total time= 1.7min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.990, test=0.856) roc: (train=1.000, test=0.975) total time= 1.5min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.991, test=0.792) roc: (train=1.000, test=0.983) total time= 1.6min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.989, test=0.770) roc: (train=1.000, test=0.962) total time= 1.5min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=10, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.987, test=0.856) roc: (train=1.000, test=0.958) total time= 1.5min
#
# Лучшие параметры:
# classifier__criterion -> entropy
# classifier__max_depth -> None
# classifier__max_features -> sqrt
# classifier__min_samples_leaf -> 1
# classifier__min_samples_split -> 2
#
# Лучшая средняя PR-AUC (CV): 0.8472271602900449
# Соответствующий ROC-AUC (CV): 0.9478521341480878
# Точность на тесте: 0.8802190108930732

# %% [markdown]
# # 2.2. Random Search

# %%
from sklearn.model_selection import RandomizedSearchCV

random_search = RandomizedSearchCV(
    estimator=pipeline,
    param_distributions=param_grid,
    n_iter=16,
    scoring={"pr": "average_precision", "roc": "roc_auc"},
    refit="pr",
    cv=cv,
    n_jobs=-1,
    verbose=3,
    return_train_score=True
)

random_search.fit(X_train, y_train)

# Результаты
print("\nЛучшие параметры:")
for key, value in random_search.best_params_.items():
    print(f'{key} -> {value}')
print("\nЛучшее качество на кросс-валидации:", random_search.best_score_)
print("Точность на тесте:", random_search.score(X_test, y_test))
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.990, test=0.858) roc: (train=1.000, test=0.966) total time= 1.1min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.888) roc: (train=1.000, test=0.960) total time= 1.1min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.998, test=0.862) roc: (train=1.000, test=0.960) total time= 1.1min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.997, test=0.778) roc: (train=1.000, test=0.921) total time= 1.1min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.990, test=0.894) roc: (train=1.000, test=0.972) total time= 1.1min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.831) roc: (train=1.000, test=0.954) total time= 1.1min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.777) roc: (train=1.000, test=0.909) total time= 1.1min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.997, test=0.893) roc: (train=1.000, test=0.972) total time= 1.1min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.867) roc: (train=1.000, test=0.942) total time= 1.1min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.988, test=0.856) roc: (train=1.000, test=0.953) total time= 1.1min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.998, test=0.858) roc: (train=1.000, test=0.946) total time= 1.1min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.998, test=0.796) roc: (train=1.000, test=0.965) total time= 1.1min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.874) roc: (train=1.000, test=0.974) total time= 1.1min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.992, test=0.828) roc: (train=1.000, test=0.965) total time= 1.1min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.987, test=0.888) roc: (train=1.000, test=0.972) total time= 1.2min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.990, test=0.764) roc: (train=1.000, test=0.925) total time= 1.2min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.987, test=0.855) roc: (train=1.000, test=0.940) total time= 1.2min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.989, test=0.860) roc: (train=1.000, test=0.965) total time= 1.2min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.991, test=0.764) roc: (train=1.000, test=0.932) total time= 1.2min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.990, test=0.820) roc: (train=1.000, test=0.966) total time= 1.2min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.998, test=0.868) roc: (train=1.000, test=0.973) total time= 2.9min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.999, test=0.896) roc: (train=1.000, test=0.967) total time= 2.9min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.899) roc: (train=1.000, test=0.973) total time= 2.9min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.788) roc: (train=1.000, test=0.922) total time= 2.9min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.854) roc: (train=1.000, test=0.967) total time= 2.9min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.860) roc: (train=1.000, test=0.941) total time= 3.0min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=1.000, test=0.813) roc: (train=1.000, test=0.954) total time= 3.0min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=1.000, test=0.818) roc: (train=1.000, test=0.966) total time= 3.1min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.845, test=0.812) roc: (train=0.998, test=0.991) total time=  53.4s
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.992, test=0.871) roc: (train=1.000, test=0.967) total time= 2.8min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.989, test=0.899) roc: (train=1.000, test=0.966) total time= 2.8min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.861, test=0.754) roc: (train=0.998, test=0.992) total time=  52.6s
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.999, test=0.789) roc: (train=1.000, test=0.933) total time= 2.9min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.999, test=0.866) roc: (train=1.000, test=0.954) total time= 3.0min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.994, test=0.820) roc: (train=1.000, test=0.966) total time= 3.0min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.990, test=0.862) roc: (train=1.000, test=0.941) total time= 3.0min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.858, test=0.818) roc: (train=0.998, test=0.978) total time=  52.8s
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.866, test=0.817) roc: (train=0.997, test=0.963) total time=  51.4s
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.886, test=0.734) roc: (train=0.998, test=0.979) total time=  52.9s
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.845, test=0.817) roc: (train=0.998, test=0.993) total time=  52.2s
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.865, test=0.739) roc: (train=0.998, test=0.991) total time=  52.4s
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.865, test=0.822) roc: (train=0.998, test=0.965) total time=  53.6s
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.858, test=0.820) roc: (train=0.998, test=0.980) total time=  54.7s
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.883, test=0.732) roc: (train=0.998, test=0.978) total time=  53.8s
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.860, test=0.829) roc: (train=0.998, test=0.992) total time=  50.2s
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.870, test=0.782) roc: (train=0.998, test=0.992) total time=  50.1s
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.989, test=0.894) roc: (train=1.000, test=0.966) total time= 2.8min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.991, test=0.874) roc: (train=1.000, test=0.966) total time= 2.8min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.992, test=0.775) roc: (train=1.000, test=0.932) total time= 2.8min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.863, test=0.824) roc: (train=0.998, test=0.979) total time=  49.6s
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.867, test=0.825) roc: (train=0.998, test=0.964) total time=  49.3s
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.885, test=0.739) roc: (train=0.998, test=0.980) total time=  48.2s
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.989, test=0.858) roc: (train=1.000, test=0.947) total time= 2.8min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.991, test=0.776) roc: (train=1.000, test=0.920) total time= 2.8min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=None, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.992, test=0.812) roc: (train=1.000, test=0.972) total time= 2.9min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.855, test=0.820) roc: (train=0.998, test=0.992) total time=  47.8s
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.869, test=0.777) roc: (train=0.998, test=0.992) total time=  49.2s
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.861, test=0.819) roc: (train=0.998, test=0.979) total time=  49.4s
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.884, test=0.733) roc: (train=0.998, test=0.979) total time=  51.6s
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.868, test=0.823) roc: (train=0.998, test=0.962) total time=  52.7s
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.895, test=0.778) roc: (train=0.999, test=0.988) total time= 2.5min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.882, test=0.859) roc: (train=0.999, test=0.988) total time= 2.4min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.886, test=0.859) roc: (train=0.999, test=0.988) total time= 2.5min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.891, test=0.831) roc: (train=0.999, test=0.977) total time= 2.5min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.912, test=0.737) roc: (train=0.999, test=0.978) total time= 2.5min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.895, test=0.773) roc: (train=0.999, test=0.989) total time= 2.4min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.889, test=0.832) roc: (train=0.999, test=0.977) total time= 2.4min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2; pr: (train=0.889, test=0.810) roc: (train=0.999, test=0.976) total time= 2.5min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.910, test=0.738) roc: (train=0.999, test=0.977) total time= 2.4min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.887, test=0.868) roc: (train=0.999, test=0.990) total time= 2.4min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=10; pr: (train=0.889, test=0.806) roc: (train=0.999, test=0.974) total time= 2.5min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.896, test=0.769) roc: (train=0.999, test=0.989) total time= 2.4min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.890, test=0.827) roc: (train=0.999, test=0.976) total time= 2.1min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.893, test=0.815) roc: (train=0.999, test=0.975) total time= 2.2min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=2; pr: (train=0.917, test=0.742) roc: (train=0.999, test=0.980) total time= 1.2min
# [CV 1/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.886, test=0.868) roc: (train=0.999, test=0.989) total time= 1.2min
# [CV 2/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.895, test=0.768) roc: (train=0.999, test=0.989) total time= 1.2min
# [CV 3/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.890, test=0.827) roc: (train=0.999, test=0.977) total time= 1.2min
# [CV 5/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.917, test=0.742) roc: (train=0.999, test=0.979) total time= 1.1min
# [CV 4/5] END classifier__criterion=entropy, classifier__max_depth=5, classifier__max_features=0.5, classifier__min_samples_leaf=4, classifier__min_samples_split=10; pr: (train=0.894, test=0.814) roc: (train=0.999, test=0.974) total time= 1.2min
#
# Лучшие параметры:
# classifier__min_samples_split -> 2
# classifier__min_samples_leaf -> 1
# classifier__max_features -> sqrt
# classifier__max_depth -> None
# classifier__criterion -> entropy
#
# Лучшее качество на кросс-валидации: 0.8472271602900449
# Точность на тесте: 0.8802190108930732

# %% [markdown]
# # 2.3. Optuna

# %%
import optuna
from sklearn.model_selection import cross_val_score


optuna.logging.disable_default_handler()


def objective_dt(trial):
    max_depth = trial.suggest_int('classifier__max_depth', 1, 5)
    min_samples_split = trial.suggest_int(
        'classifier__min_samples_split', 2, 4)
    min_samples_leaf = trial.suggest_int('classifier__min_samples_leaf', 1, 4)
    criterion = trial.suggest_categorical(
        'classifier__criterion', ['entropy'])

    pipeline.set_params(
        classifier__max_depth=max_depth,
        classifier__min_samples_split=min_samples_split,
        classifier__min_samples_leaf=min_samples_leaf,
        classifier__criterion=criterion
    )

    score = cross_val_score(pipeline, X_train, y_train,
                            cv=cv, scoring="average_precision").mean()
    return score


# Создаём исследование
study_dt = optuna.create_study(
    direction="maximize"  # максимизирукм cross_val_score чтобы он был наибольшим
)

study_dt.optimize(
    objective_dt,
    n_trials=60,  # количество попыток
    n_jobs=-1,
)


# Лучшие параметры
print("\nЛучшие параметры:")
for key, value in study_dt.best_params.items():
    print(f'{key} -> {value}')

pipeline.set_params(**study_dt.best_params)
pipeline.fit(X_train, y_train)
print("\nЛучшее качество на кросс-валидации:", cross_val_score(pipeline,
      X_train, y_train, cv=cv, scoring="average_precision").mean())
print("Точность на тесте:", pipeline.score(X_test, y_test))
# Out:
# Лучшие параметры:
# classifier__max_depth -> 5
# classifier__min_samples_split -> 3
# classifier__min_samples_leaf -> 3
# classifier__criterion -> entropy
#
# Лучшее качество на кросс-валидации: 0.7946922865296099
# Точность на тесте: 0.9983322214809873

# %% [markdown]
# # 2.4. TPOT

# %%
os.environ["PYTHONWARNINGS"] = "ignore:::pkg_resources"

# На всякий случай приглушим и на уровне интерпретатора
warnings.filterwarnings("ignore", category=UserWarning, module="pkg_resources")

# %%
from tpot import TPOTClassifier
from sklearn.metrics import precision_score


# Создаём TPOT-классификатор
tpot = TPOTClassifier(
    generations=3,        # количество поколений эволюций
    population_size=10,   # размер популяции
    verbose=2,            # уровень детализации вывода
    random_state=RND_SEED,
    cv=5,                 # количество фолдов кросс-валидации
)

# %%
warnings.filterwarnings(
    "ignore",
    message="Both generations and max_time_mins are set. TPOT will terminate when the first condition is met.",
    category=UserWarning,
    module="tpot"
)

# %%
import os
import warnings
os.environ["PYTHONWARNINGS"] = "ignore"
warnings.simplefilter("ignore")

# %%
from joblib import dump
# Обучаем
print("Начало оптимизации с TPOT...")
tpot.fit(X_train, y_train)


dump(tpot.fitted_pipeline_, "tpot_pipeline.joblib")
print("Сохранено: tpot_pipeline.joblib")
# Out:
# Начало оптимизации с TPOT...
# Generation: 100%|██████████| 3/3 [47:47<00:00, 955.83s/it]
# Сохранено: tpot_pipeline.joblib

# %%
from sklearn.metrics import accuracy_score

# %%
# Оценка качества
y_pred = tpot.predict(X_test)
test_pr = accuracy_score(y_test, y_pred)
print(f"Точность на тестовой выборке: {test_pr:.4f}")

# Лучшие параметры и конвейер
print("\nЛучший конвейер:")
print(tpot.fitted_pipeline_)
# Out:
# Точность на тестовой выборке: 0.9995
#
# Лучший конвейер:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('selectfwe', SelectFwe(alpha=0.0012903345738)),
#                 ('featureunion-1',
#                  FeatureUnion(transformer_list=[('featureunion',
#                                                  FeatureUnion(transformer_list=[('columnordinalencoder',
#                                                                                  ColumnOrdinalEncoder()),
#                                                                                 ('binarizer',
#                                                                                  Binarizer(threshold=0.55347461412))])),
#                                                 ('passthrough',
#                                                  Passthrough())])),
#                 ('featureunion-2',
#                  FeatureUnion(transformer_list=[('skiptransformer',
#                                                  SkipTransformer()),
#                                                 ('passthrough',
#                                                  Passthrough())])),
#                 ('mlpclassifier',
#                  MLPClassifier(activation=np.str_('logistic'),
#                                alpha=0.0004588425425, early_stopping=np.True_,
#                                hidden_layer_sizes=[368, 368],
#                                learning_rate=np.str_('invscaling'),
#                                learning_rate_init=0.0009543257851,
#                                n_iter_no_change=32, random_state=42))])

# %% [markdown]
# # 3. Сравнение результатов

# %%
import pandas as pd
from IPython.display import display

# Данные из твоего сообщения
rows = [
    {
        "Метод": "Grid Search",
        "Лучшие параметры": {
            "classifier__criterion": "entropy",
            "classifier__max_depth": None,
            "classifier__max_features": "sqrt",
            "classifier__min_samples_leaf": 1,
            "classifier__min_samples_split": 2,
        },
        "PR-AUC (CV)": 0.8472271602900449,
        "ROC-AUC (CV)": 0.9478521341480878,
        "Accuracy (тест)": 0.8802190108930732,
    },
    {
        "Метод": "Random Search",
        "Лучшие параметры": {
            "classifier__criterion": "entropy",
            "classifier__max_depth": None,
            "classifier__max_features": "sqrt",
            "classifier__min_samples_leaf": 1,
            "classifier__min_samples_split": 2,
        },
        "PR-AUC (CV)": 0.8472271602900449,
        "ROC-AUC (CV)": None,
        "Accuracy (тест)": 0.8802190108930732,
    },
    {
        "Метод": "Optuna",
        "Лучшие параметры": {
            "classifier__criterion": "entropy",
            "classifier__max_depth": 5,
            "classifier__min_samples_leaf": 3,
            "classifier__min_samples_split": 3,
        },
        "PR-AUC (CV)": 0.7946922865296099,
        "ROC-AUC (CV)": None,
        "Accuracy (тест)": 0.9983322214809873,
    },
]

df = pd.DataFrame(rows)[["Метод", "Лучшие параметры",
                         "PR-AUC (CV)", "ROC-AUC (CV)", "Accuracy (тест)"]]
df_sorted = df.sort_values(
    by="Accuracy (тест)", ascending=False).reset_index(drop=True)

display(df_sorted)
# Out:
#            Метод                                   Лучшие параметры  \
# 0         Optuna  {'classifier__criterion': 'entropy', 'classifi...
# 1    Grid Search  {'classifier__criterion': 'entropy', 'classifi...
# 2  Random Search  {'classifier__criterion': 'entropy', 'classifi...
#
#    PR-AUC (CV)  ROC-AUC (CV)  Accuracy (тест)
# 0     0.794692           NaN         0.998332
# 1     0.847227      0.947852         0.880219
# 2     0.847227           NaN         0.880219
